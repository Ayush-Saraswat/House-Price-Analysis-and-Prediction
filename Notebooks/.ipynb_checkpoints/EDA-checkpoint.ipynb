# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor

sns.set_style("whitegrid")

plt.rcParams["figure.figsize"] = (10,6)

df = pd.read_csv('cleaned_train.csv')


# Show all rows
pd.set_option('display.max_rows', None)

# Show all columns
pd.set_option('display.max_columns', None)

# Show full content inside each cell (no text truncation)
pd.set_option('display.max_colwidth', None)

# Prevent wrapping to a new line
pd.set_option('display.width', None)

# %% [markdown]
# # Dataset Overview

# %%
print("Shape of Dataset :", df.shape)

display(df.head())

display(df.info())
# Out:
# Shape of Dataset : (1460, 219)
#    Unnamed: 0.1  Unnamed: 0  Id  MSSubClass  LotFrontage  LotArea  Utilities  \
# 0             0           0   1          60         65.0     8450          4
# 1             1           1   2          20         80.0     9600          4
# 2             2           2   3          60         68.0    11250          4
# 3             3           3   4          70         60.0     9550          4
# 4             4           4   5          60         84.0    14260          4
#
#    LandSlope  OverallQual  OverallCond  ...  HasPorch  OutdoorLuxury  HasPool  \
# 0          2            7            5  ...         1             61        0
# 1          2            6            8  ...         0            298        0
# 2          2            7            5  ...         1             42        0
# 3          2            7            5  ...         1            307        0
# 4          2            8            5  ...         1            276        0
#
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
display(df.describe().T)
# Out:
#                   count        mean         std        min         25%  \
# Unnamed: 0.1     1460.0  729.500000  421.610009   0.000000  364.750000
# Unnamed: 0       1460.0  729.500000  421.610009   0.000000  364.750000
# Id               1460.0  730.500000  421.610009   1.000000  365.750000
# MSSubClass       1460.0   56.897260   42.300571  20.000000   20.000000
# LotFrontage      1460.0   57.623288   34.664304   0.000000   42.000000
# ...                 ...         ...         ...        ...         ...
# BasementScore    1460.0   28.950685   16.207201   0.000000   18.000000
# OverallScore     1460.0   33.864384    9.219624   1.000000   30.000000
# ExteriorScore    1460.0   10.473288    2.105829   3.000000    9.000000
# LuxuryScore      1460.0   16.152055    2.994654   6.000000   14.000000
# LivingAreaRatio  1460.0    0.594603    0.109816   0.336849    0.499832
#
#                        50%          75%          max
# Unnamed: 0.1     729.50000  1094.250000  1459.000000
# ...

# %% [markdown]
# # Final Checking for missing values

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]

print("Remaining Missing Values :", len(missing))

display(missing.sort_values(ascending=False))
# Out:
# Remaining Missing Values : 0
# Series([], dtype: int64)

# %% [markdown]
# # Distribution of House Prices

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["SalePrice"], bins=40, kde=True)

plt.title("Distribution of House Prices")
plt.xlabel("Sale Price")
plt.ylabel("Count")

plt.show()

# %%
corr = df.corr(numeric_only=True)

sale_corr = (
    corr["SalePrice"]
    .sort_values(ascending=False)
)

display(sale_corr)
# Out:
# SalePrice                 1.000000
# BathQualityInteraction    0.819640
# OverallQual               0.817185
# LuxuryScore               0.807407
# TotalArea                 0.777297
# GrLivArea                 0.700927
# TotalFinishedSF           0.698492
# ExterQual                 0.678840
# TotalBathrooms            0.673011
# KitchenQual               0.667893
# KitchenPremium            0.666723
# GarageArea                0.650888
# RoomDensity               0.636987
# BsmtQual                  0.615804
# TotalBsmtSF               0.612134
# HouseAgeBin               0.608107
# OverallScore              0.606873
# GarageEra                 0.606337
# 1stFlrSF                  0.596981
# FullBath                  0.594771
# YearBuilt                 0.586570
# ExteriorScore             0.586472
# YearRemodAdd              0.565608
# FireplaceQuNum            0.546362
# FireplaceParameter        0.542288
# BasementScore             0.539652
# TotRmsAbvGrd              0.534422
# ...

# %% [markdown]
# # Top 15 correlated features

# %%
top_corr = sale_corr[1:16]

plt.figure(figsize=(8,7))

sns.barplot(
    x=top_corr.values,
    y=top_corr.index
)

plt.title("Top Features Correlated with Sale Price")
plt.xlabel("Correlation")
plt.ylabel("Features")

plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
top_features = sale_corr.abs().sort_values(ascending=False).head(11).index

plt.figure(figsize=(10,8))

sns.heatmap(
    df[top_features].corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap of Top Features")

plt.show()

# %%
# Get top 6 correlated features (excluding SalePrice itself)
important_features = (
    df.corr(numeric_only=True)["SalePrice"]
    .drop("SalePrice")
    .abs()
    .sort_values(ascending=False)
    .head(6)
    .index
)

fig, axes = plt.subplots(2, 3, figsize=(16, 10))

for ax, feature in zip(axes.flatten(), important_features):

    sns.scatterplot(
        data=df,
        x=feature,
        y="SalePrice",
        alpha=0.6,
        ax=ax
    )

    ax.set_title(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Importance

# %%
X = df.drop("SalePrice", axis=1)

y = df["SalePrice"]

model = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

model.fit(X, y)

importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

display(importance.head(10))
# Out:
#                     Feature  Importance
# 199  BathQualityInteraction    0.489014
# 190               TotalArea    0.164675
# 191         TotalFinishedSF    0.077049
# 8               OverallQual    0.043814
# 216             LuxuryScore    0.029052
# 214            OverallScore    0.028536
# 40               GarageArea    0.012953
# 5                   LotArea    0.009164
# 27                 1stFlrSF    0.007222
# 23              TotalBsmtSF    0.006848

# %% [markdown]
# # Top 10 most important features

# %%
top10 = importance.head(10)

plt.figure(figsize=(10,6))

sns.barplot(
    data=top10,
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Features Influencing House Prices")

plt.xlabel("Feature Importance")

plt.ylabel("Feature")

plt.show()

# %% [markdown]
# # Pairplot of top features

# %%
pair_features = list(top10["Feature"][:5])

pair_features.append("SalePrice")

sns.pairplot(
    df[pair_features],
    corner=True
)

plt.show()
